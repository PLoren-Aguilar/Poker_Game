# %% [markdown]
# <h2> Poker Texas Hold'em Game </h2>
# <h3> Author: Pablo Loren-Aguilar </h3>

# %%
hands = [player1_cards, player2_cards]
evaluator.hand_summary(common_cards,hands)

# %%
import pygame
import sys
import random as rnd
import string
import include.player as player
import include.table as table
import include.menu as menu
from include.treys.treys import Card
from include.treys.treys import Evaluator
from include.treys.treys import Deck

pygame.init()

#Create the players
nplayers = 4
players  = []
croupier = table.newtable(nplayers,players)
        
#Create game window and title
screen = menu.newmenu()
surface = pygame.display.set_mode((1200, 1200))
surface.fill((255,255,255))

#Initialise cards' tools
card = Card()

endgame = False
while (endgame == False):
    screen.create_table(surface)
    screen.put_all_cards(surface,len(croupier.players_order),players)
    screen.put_buttons(surface,croupier.players_order,1)
    screen.remove_chips(surface)

    #Initialise the deck of cards
    deck = Deck()
    
    #Give every player a hand
    print(players)
    croupier.set_hand(players,deck)

    #Reveal player's hand
    if (players[0].cash > 0):
        screen.player_cards(surface,players[0].cards,0)

    #Put the blinds for this round
    screen.show_blinds(surface)
    screen.put_blinds(surface,croupier.players_order)
    
    #Put the common cards on the table
    croupier.set_common(deck)
    pygame.display.update()
    
    #Pre-flop
    croupier.set_bet('preflop')
    croupier.bet_round(screen,surface,card,players,'preflop')
    
    #Flop
    croupier.set_bet('postflop')
    croupier.bet_round(screen,surface,card,players,'flop')

    #Turn
    croupier.set_bet('postflop')
    croupier.bet_round(screen,surface,card,players,'turn')

    #River
    croupier.set_bet('postflop')
    croupier.bet_round(screen,surface,card,players,'river')
    
    #Check Winner
    croupier.check_winner(screen,surface,players,card)
    
    #players[winner].cash += croupier.pot  
    croupier.pot = 0
    
    #Check if any player has been eliminated and reactivate any active but folded player
    for indx,player in enumerate(players):
        if (player.cash == 0):
            pass
            #player.active = False
        else:
            if (player.folded == True):
                player.folded = False        
      
    #Clean the table and prepare for a new round 
    surface = pygame.display.set_mode((1200, 1200)) 
    surface.fill((255,255,255))
    croupier.set_dealer(players)

pygame.quit()
sys.exit()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# [<include.player.newplayer object at 0x0000029803240CC8>, <include.player.newplayer object at 0x0000029804864F48>, <include.player.newplayer object at 0x00000298055F3548>, <include.player.newplayer object at 0x00000298055F35C8>]
# [295429, 1057803, 16795671, 134228773, 2102541, 8398611, 2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [295429, 1057803, 16795671, 134228773, 2102541, 8398611, 2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [1057803, 16795671, 134228773, 2102541, 8398611, 2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [16795671, 134228773, 2102541, 8398611, 2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [16795671, 134228773, 2102541, 8398611, 2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [134228773, 2102541, 8398611, 2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [2102541, 8398611, 2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [2102541, 8398611, 2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [8398611, 2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [2106637, 67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [67115551, 139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [139523, 134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [134224677, 268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [268446761, 4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [4199953, 268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [268471337, 67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [139523, 134224677, 268446761, 4199953, 268471337]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [<include.player.newplayer object at 0x0000029803240CC8>, <include.player.newplayer object at 0x0000029804864F48>, <include.player.newplayer object at 0x00000298055F3548>, <include.player.newplayer object at 0x00000298055F35C8>]
# [67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [67144223, 541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [541447, 16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [16787479, 81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [81922, 266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [266757, 33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [33589533, 557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [557831, 33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [33573149, 4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [4228625, 134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [134253349, 73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [73730, 16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [16783383, 270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [270853, 1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [4228625, 134253349, 73730, 16783383, 270853]
# [<include.player.newplayer object at 0x0000029803240CC8>, <include.player.newplayer object at 0x0000029804864F48>, <include.player.newplayer object at 0x00000298055F3548>, <include.player.newplayer object at 0x00000298055F35C8>]
# [1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [1053707, 147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [147715, 33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [33564957, 268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [268442665, 67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [67119647, 2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [2114829, 8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [8394515, 2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [2131213, 135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [135427, 1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [1065995, 67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [67127839, 533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [533255, 4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [4204049, 164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [135427, 1065995, 67127839, 533255, 4204049]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [<include.player.newplayer object at 0x0000029803240CC8>, <include.player.newplayer object at 0x0000029804864F48>, <include.player.newplayer object at 0x00000298055F3548>, <include.player.newplayer object at 0x00000298055F35C8>]
# [164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [164099, 69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [69634, 98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [98306, 529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [529159, 268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [268454953, 8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [8406803, 8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [8423187, 279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [279045, 134236965, 4212241, 16812055, 33560861, 1082379]
# [134236965, 4212241, 16812055, 33560861, 1082379]
# [134236965, 4212241, 16812055, 33560861, 1082379]
# [4212241, 16812055, 33560861, 1082379]
# [16812055, 33560861, 1082379]
# [33560861, 1082379]
# [1082379]
# [134236965, 4212241, 16812055, 33560861, 1082379]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [<include.player.newplayer object at 0x0000029803240CC8>, <include.player.newplayer object at 0x0000029804864F48>, <include.player.newplayer object at 0x00000298055F3548>, <include.player.newplayer object at 0x00000298055F35C8>]
# []
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-d31e78f4e19c> in <module>
#      35     #Give every player a hand
#      36     print(players)
# ---> 37     croupier.set_hand(players,deck)
#      38
#      39     #Reveal player's hand
#
# ~\Documents\Python_Learning\Poker_Game\include\table.py in set_hand(self, players, deck)
#      90     def set_hand(self,players,deck):
#      91         for person in players:
# ---> 92             person.cards = deck.draw(2)
#      93
#      94     def bet_round(self,screen,surface,card,players,n):
#
# ~\Documents\Python_Learning\Poker_Game\include\treys\treys\deck.py in draw(self, n)
#      27         cards = []
#      28         for i in range(n):
# ---> 29             cards.append(self.draw())
#      30         return cards
#      31
#
# ~\Documents\Python_Learning\Poker_Game\include\treys\treys\deck.py in draw(self, n)
#      23
#      24         if n == 1:
# ---> 25             return self.cards.pop(0)
#      26
#      27         cards = []
#
# IndexError: pop from empty list

# %%
from include.treys.treys import Card
from include.treys.treys import Evaluator
from include.treys.treys import Deck
hand_rankings = ("High Card", "Pair", "Two Pair", "Three of a Kind",
                 "Straight", "Flush", "Full House", "Four of a Kind",
                 "Straight Flush", "Royal Flush")

card = Card()
deck = Deck()
hand1 = deck.draw(2)
hand2 = deck.draw(2)
board = deck.draw(3)

hand_str = []
for cards in hand1:
    hand_str.append(card.int_to_str(cards))

for cards in hand2:
    hand_str.append(card.int_to_str(cards))
print(hand_str)

board_str = []
commons = []
for cards in board:
    board_str.append(card.int_to_str(cards))
    commons.append(cards)
    #print(card.get_rank_int(cards),card.get_suit_int(cards))
print(board_str)

board_str = None
hand_str = ['As', 'Ac', '?', '?']
#hand_str = ['?','?','Kc', '8c']

from include.holdem_probs import holdem_calc

result = holdem_calc.calculate(board_str, False, 10, None, hand_str,False)

print('result=',result[0][0],result[0][1],result[0][2])
for item in result[1]:
    print("Player:",item[0])
    for indx,value in enumerate(item[1]):
        print(hand_rankings[indx],value)
    print('Best hand for player', item[0], hand_rankings[item[1].index(max(item[1]))],max(item[1]))
    print("--------------")
    
print(hand_str[1][0])

# %%
A = [1,2,3,4]

# %%
print(A[4])
